# %% [markdown]
# <a href="https://colab.research.google.com/github/alighaderian57/Colab/blob/main/paddleocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m pip install paddlepaddle -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...

# %%
# !pip install paddleocr

# %%
# !git clone https://github.com/PaddlePaddle/PaddleOCR
# Out:
# fatal: destination path 'PaddleOCR' already exists and is not an empty directory.

# %%
from paddleocr import PaddleOCR, draw_ocr
import matplotlib.pyplot as plt
from PIL import Image

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='fa', use_gpu=False)
# Out:
# [2024/05/26 05:44:18] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/ml/Multilingual_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/arabic/arabic_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, 
# ...

# %%
image_path = '/content/3.jpg'
img = Image.open(image_path)

# %%
result = ocr.ocr(image_path, cls=True)
# Out:
# [2024/05/26 05:47:04] ppocr DEBUG: dt_boxes num : 78, elapsed : 0.16683268547058105
# [2024/05/26 05:47:05] ppocr DEBUG: cls num  : 78, elapsed : 0.2144303321838379
# [2024/05/26 05:47:09] ppocr DEBUG: rec_res num  : 78, elapsed : 4.183257818222046

# %%
for line in result:
  print(line)
# Out:
# [[[[385.0, 293.0], [522.0, 298.0], [522.0, 320.0], [384.0, 316.0]], ('تسود ترضح مان هب', 0.9396939277648926)], [[[116.0, 311.0], [190.0, 319.0], [188.0, 342.0], [114.0, 334.0]], ('هعلاطم ار', 0.8767269849777222)], [[[181.0, 320.0], [254.0, 323.0], [253.0, 343.0], [180.0, 340.0]], ('ريز دراوم', 0.9405908584594727)], [[[250.0, 320.0], [518.0, 327.0], [518.0, 354.0], [249.0, 346.0]], ('نيرمت هبلرش  لبرق  لارب  عوجره', 0.654640257358551)], [[[117.0, 344.0], [144.0, 344.0], [144.0, 360.0], [117.0, 360.0]], ('لمع', 0.998924970626831)], [[[149.0, 342.0], [187.0, 346.0], [185.0, 365.0], [147.0, 361.0]], ('تاكن', 0.992992639541626)], [[[190.0, 348.0], [215.0, 348.0], [215.0, 365.0], [190.0, 365.0]], ('نيا', 0.9595389366149902)], [[[215.0, 351.0], [239.0, 351.0], [239.0, 365.0], [215.0, 365.0]], ('هب', 0.9985477924346924)], [[[234.0, 352.0], [279.0, 352.0], [279.0, 367.0], [234.0, 367.0]], ('نيرمت', 0.9931565523147583)], [[[280.0, 347.0], [334.0, 353.0], [332.0, 371.0], [278.0, 366.0]], ('لحار
# ...

# %%
boxes = [line[0] for line in result[0]]
txts = [line[1][0] for line in result[0]]
scores = [line[1][1] for line in result[0]]

# %%
for txt in txts:
  print(txt)
# Out:
# تسود ترضح مان هب
# هعلاطم ار
# ريز دراوم
# نيرمت هبلرش  لبرق  لارب  عوجره
# لمع
# تاكن
# نيا
# هب
# نيرمت
# لحارم
# ىمامت
# رد
# دينك
# ىعس
# و هدومت
# ترضح
# ىرايو امش موادم
# نيرمت
# و شال اب تسا
# ديما
# .ديئامن
# .ديوش دنم مرهب ىيلئاوخ و شتوخ طقف
# زا جيئاوشب قح
# .ديننك
# هاكن تقد اب بوخ ادتبا
# 1
# ديوب ر ر ر ر بزا رابدنج(
# هدافتسا
# كلاك اي ىتسوب
# دينك
# ذغاك ك بك ك ىارب
# .دينك د  اب سيس
# هوزج
# نيا
# تانيرمت
# و
# اهسرد نم مامتا هنمتا زا سب
# ىاه
# ىسراف
# باتك
# لثم فلتخم
# بتتك
# ىاه
# نتم زا دييناوت ىم
# دينك هدافتسا
# نيرش تعج
# ييأا دتبا
# هرود
# دادم زين
# و دينك
# هدافتسا
# راد طخ
# ذغاك
# زا نتشون ىارب
#
# بسانم
# نتشون
# ىارب
# سيون
# ناور
# سيوندوخ
# راكدوخ
# دنتسه
# .دينك نيرمت هتسهأ
# و هدركن هلجع
# نتشون رد
# و
# هتفركتئارف و هدرتن نيرش
# أالماك
# ار سرد هكنيا
# زا لبق
# .دينكن عورش
# ار دعب سرد ديا

# %%
img = Image.open(image_path).convert('RGB')
im_show = draw_ocr(img, boxes, txts, scores, font_path='/content/ARIAL.TTF')  # Specify the path to a Farsi-supporting font
im_show = Image.fromarray(im_show)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(im_show)
plt.axis('off')
plt.show()
